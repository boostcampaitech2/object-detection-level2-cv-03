# %%
import torch
import numpy as np
from mmcv import Config
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

import os
import sys
# sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('boostcamp'))))
# tmp = os.getcwd()
# os.chdir('../../../mmdetection/boostcamp/augmentation/augmixations')
# from augmixations.cutmix import SmartCutmix
# os.chdir(tmp)
# from augmentation.Cutmix_Augmentation import Cutmix_Augmentation

# %% [markdown]
# ### model load

# %%
MODEL_PATH ='/opt/ml/detection/mmdetection/configs/vfnet/vfnet_r50_fpn_mdconv_c3-c5_mstrain_2x_coco.py'

MODEL = 'vfnet_resnest50_fpn_mdconv_c3-c5_mstrain_2x_coco'
#NAME = ''
WORK_DIR =MODEL
# config file 들고오기
cfg = Config.fromfile(MODEL_PATH)

# data config
dataset_type = 'CocoDataset'
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")
num_classes = len(classes)

root = '/opt/ml/detection/dataset/'

cfg.data.samples_per_gpu = 8
cfg.data.workers_per_gpu = 4

cfg.data.train.classes= classes
cfg.data.train.ann_file = root+'kfold/cv_train1.json'
cfg.data.train.img_prefix = root


cfg.data.val.classes = classes
cfg.data.val.ann_file = root+'kfold/cv_val1.json'
cfg.data.val.img_prefix = root

cfg.data.test.classes = classes
cfg.data.test.ann_file = root+'test.json'
cfg.data.test.img_prefix = root

img_norm_cfg = dict(
    mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)


cfg.data.train.pipeline[2].img_scale = [(1024, 512), (1024, 768)]
cfg.data.train.pipeline[2].multiscale_mode = 'range'
cfg.data.val.pipeline[1].img_scale = [(512,512),(840,840),(1024, 1024)]
cfg.data.test.pipeline[1].img_scale = [(512,512),(840,840),(1024, 1024)]
# # for TTA
# cfg.data.test.pipeline[1].flip=True
# cfg.data.val.pipeline[1].flip=True

cfg.data.test.test_mode = True
#cfg.data.val.test_mode = True

cfg.data['train'] = dict(
        type='ClassBalancedDataset',
        oversample_thr=1e-3,
        dataset= cfg.data['train'])

# Build dataset
datasets = build_dataset(cfg.data.train)

# model config
cfg.model.bbox_head.num_classes = num_classes
cfg.model.test_cfg.score_thr =0
cfg.model.test_cfg.nms.type='soft_nms'



# cfg.model.neck =dict(
#         type='PAFPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         start_level=1,
#         add_extra_convs ='on_output',
#         num_outs=5,
#         relu_before_extra_convs= True)

# weighted loss config , 분포 구하기
instance_count = np.zeros(num_classes).astype(int)
for idx in range(len(datasets)):
    label = datasets.dataset.get_ann_info(idx)['labels']
    unique, counts = np.unique(label, return_counts=True)
    
    # add the occurrence number to each class
    instance_count[unique] += counts
    
normedWeights = [1 - (x / sum(instance_count)) for x in instance_count]
normedWeights = torch.FloatTensor(normedWeights).cuda()

## loss에 등록
cfg.model.bbox_head.loss_cls.loss_weight = normedWeights


##ptimizer config
cfg.optimizer.lr =cfg.optimizer.lr * cfg.data.samples_per_gpu**(1/2)
cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)

## other config
cfg.checkpoint_config = dict(interval=1)
cfg.seed = 1010
cfg.gpu_ids = [0]
cfg.work_dir = f'../work_dirs/{WORK_DIR}'

cfg.evaluation = dict(
    save_best='bbox_mAP',
    metric=['bbox']
)

# wandb
log_config = dict(
    interval=10,
    hooks=[
        dict(type='TextLoggerHook'),
        dict(
            type='WandbLoggerHook',
            init_kwargs=dict(
                project='p-stage_object_detection',
#                entity='boostcampaitech2-object-detection-level2-cv-03',
                name=f'{WORK_DIR}'))])
cfg.log_config = log_config

# learning policy
lr_config = dict(
    policy='step',
    warmup='linear',
    warmup_iters=500,
    warmup_ratio=0.001,
    gamma=0.2,
    step=[16, 22,28,34])
runner = dict(type='EpochBasedRunner', max_epochs=40)

# cfg.runner.max_epochs=40
# cfg.lr_config = dict(
#     policy='cyclic',
#     target_ratio=(10, 1e-4),
#     cyclic_times=1,
#     step_ratio_up=0.4,
# )
# cfg.momentum_config = dict(
#     policy='cyclic',
#     target_ratio=(0.85 / 0.95, 1),
#     cyclic_times=1,
#     step_ratio_up=0.4,
# )
# Out:
# loading annotations into memory...
# Done (t=0.22s)
# creating index...
# index created!

# %% [markdown]
# ### save config for test

# %%
import pickle
import os
os.makedirs(cfg.work_dir,exist_ok=True)
with open(os.path.join(cfg.work_dir,'cfg.pkl'),'wb') as f:
    pickle.dump(cfg,f)

# %% [markdown]
# ## train

# %%
# Build the detector
model = build_detector(cfg.model)
model.init_weights()
# Out:
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmdet/core/anchor/builder.py:17: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# 2021-10-01 10:21:35,127 - mmcv - INFO - initialize ResNet with init_cfg {'type': 'Pretrained', 'checkpoint': 'torchvision://resnet50'}
# 2021-10-01 10:21:35,128 - mmcv - INFO - load model from: torchvision://resnet50
# 2021-10-01 10:21:35,131 - mmcv - INFO - Use load_from_torchvision loader
# 2021-10-01 10:21:35,414 - mmcv - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# missing keys in source state_dict: layer2.0.conv2.conv_offset.weight, layer2.0.conv2.conv_offset.bias, layer2.1.conv2.conv_offset.weight, layer2.1.conv2.conv_offset.bias, layer2.2.conv2.conv_offset.weight, layer2.2.conv2.conv_offset.bias, layer2.3.conv2.conv_offset.weight, layer2.3.conv2.conv_offset.bias, layer3.0.conv2.conv_offset.weight, layer3.0.conv2.conv_offset.bias, layer3.1.conv2.conv_offset.weight, layer3.1.conv2.conv_offset.bias, layer3.2.conv2.conv_offset.weight, layer3.2.conv2.conv_offset.bias, layer3.3.conv2.conv_offset.weight, layer3.3.conv2.conv_offset.bias, layer3.4.conv2.conv_offset.weight, layer3.4.conv2.conv_offset.bias, layer3.5.conv2.conv_offset.weight, layer3.5.conv2.conv_offset.bias, layer4.0.conv2.conv_offset.weight, layer4.0.conv2.conv_offset.bias, layer4.1.conv2.conv_offset.weight, layer4.1.conv2.conv_offset.bias, layer4.2.conv2.conv_offset.weight, layer4.2.conv2.conv_offset.bias
#
# 2021-10-01 10:21:35,454 - mmcv - INFO - initialize FPN with init_cfg {'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
# 2021-10-01 10:21:35,509 - mmcv - INFO - initialize VFNetHead with init_cfg {'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01, 'override': {'type': 'Normal', 'name': 'vfnet_cls', 'std': 0.01, 'bias_prob': 0.01}}
# 2021-10-01 10:21:35,585 - mmcv - INFO -
# backbone.conv1.weight - torch.Size([64, 3, 7, 7]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,586 - mmcv - INFO -
# backbone.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,587 - mmcv - INFO -
# backbone.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,587 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,588 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,589 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,589 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,590 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,591 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,591 - mmcv - INFO -
# backbone.layer1.0.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,592 - mmcv - INFO -
# backbone.layer1.0.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,593 - mmcv - INFO -
# backbone.layer1.0.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,593 - mmcv - INFO -
# backbone.layer1.0.downsample.0.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,594 - mmcv - INFO -
# backbone.layer1.0.downsample.1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,594 - mmcv - INFO -
# backbone.layer1.0.downsample.1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,594 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,595 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,595 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,596 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,596 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,597 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,597 - mmcv - INFO -
# backbone.layer1.1.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,597 - mmcv - INFO -
# backbone.layer1.1.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,598 - mmcv - INFO -
# backbone.layer1.1.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,598 - mmcv - INFO -
# backbone.layer1.2.conv1.weight - torch.Size([64, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,599 - mmcv - INFO -
# backbone.layer1.2.bn1.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,599 - mmcv - INFO -
# backbone.layer1.2.bn1.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,600 - mmcv - INFO -
# backbone.layer1.2.conv2.weight - torch.Size([64, 64, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,600 - mmcv - INFO -
# backbone.layer1.2.bn2.weight - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,601 - mmcv - INFO -
# backbone.layer1.2.bn2.bias - torch.Size([64]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,601 - mmcv - INFO -
# backbone.layer1.2.conv3.weight - torch.Size([256, 64, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,602 - mmcv - INFO -
# backbone.layer1.2.bn3.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,602 - mmcv - INFO -
# backbone.layer1.2.bn3.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,603 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,604 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,604 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,605 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,605 - mmcv - INFO -
# backbone.layer2.0.conv2.conv_offset.weight - torch.Size([27, 128, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,606 - mmcv - INFO -
# backbone.layer2.0.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,606 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,607 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,607 - mmcv - INFO -
# backbone.layer2.0.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
# 2021-10-01 10:21:35,608 - mmcv - INFO -
# backbone.layer2.0.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,608 - mmcv - INFO -
# backbone.layer2.0.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,609 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,610 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,611 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,612 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,613 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,613 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,614 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,615 - mmcv - INFO -
# backbone.layer2.1.conv2.conv_offset.weight - torch.Size([27, 128, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,615 - mmcv - INFO -
# backbone.layer2.1.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,616 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,617 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,620 - mmcv - INFO -
# backbone.layer2.1.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,621 - mmcv - INFO -
# backbone.layer2.1.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,622 - mmcv - INFO -
# backbone.layer2.1.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,622 - mmcv - INFO -
# backbone.layer2.2.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,624 - mmcv - INFO -
# backbone.layer2.2.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,624 - mmcv - INFO -
# backbone.layer2.2.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,625 - mmcv - INFO -
# backbone.layer2.2.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,626 - mmcv - INFO -
# backbone.layer2.2.conv2.conv_offset.weight - torch.Size([27, 128, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,628 - mmcv - INFO -
# backbone.layer2.2.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,628 - mmcv - INFO -
# backbone.layer2.2.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,629 - mmcv - INFO -
# backbone.layer2.2.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,630 - mmcv - INFO -
# backbone.layer2.2.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,631 - mmcv - INFO -
# backbone.layer2.2.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,632 - mmcv - INFO -
# backbone.layer2.2.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,633 - mmcv - INFO -
# backbone.layer2.3.conv1.weight - torch.Size([128, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,634 - mmcv - INFO -
# backbone.layer2.3.bn1.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,634 - mmcv - INFO -
# backbone.layer2.3.bn1.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,635 - mmcv - INFO -
# backbone.layer2.3.conv2.weight - torch.Size([128, 128, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,636 - mmcv - INFO -
# backbone.layer2.3.conv2.conv_offset.weight - torch.Size([27, 128, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,637 - mmcv - INFO -
# backbone.layer2.3.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,638 - mmcv - INFO -
# backbone.layer2.3.bn2.weight - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,639 - mmcv - INFO -
# backbone.layer2.3.bn2.bias - torch.Size([128]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,640 - mmcv - INFO -
# backbone.layer2.3.conv3.weight - torch.Size([512, 128, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,641 - mmcv - INFO -
# backbone.layer2.3.bn3.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,642 - mmcv - INFO -
# backbone.layer2.3.bn3.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,642 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,643 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,644 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,645 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,646 - mmcv - INFO -
# backbone.layer3.0.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,646 - mmcv - INFO -
# backbone.layer3.0.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,647 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,648 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,649 - mmcv - INFO -
# backbone.layer3.0.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,649 - mmcv - INFO -
# backbone.layer3.0.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,650 - mmcv - INFO -
# backbone.layer3.0.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,651 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([1024, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,652 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,653 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,653 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,654 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
# 2021-10-01 10:21:35,655 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,655 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,656 - mmcv - INFO -
# backbone.layer3.1.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,656 - mmcv - INFO -
# backbone.layer3.1.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,657 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,657 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,658 - mmcv - INFO -
# backbone.layer3.1.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,658 - mmcv - INFO -
# backbone.layer3.1.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,659 - mmcv - INFO -
# backbone.layer3.1.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,660 - mmcv - INFO -
# backbone.layer3.2.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,660 - mmcv - INFO -
# backbone.layer3.2.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,661 - mmcv - INFO -
# backbone.layer3.2.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,661 - mmcv - INFO -
# backbone.layer3.2.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,662 - mmcv - INFO -
# backbone.layer3.2.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,663 - mmcv - INFO -
# backbone.layer3.2.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,663 - mmcv - INFO -
# backbone.layer3.2.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,664 - mmcv - INFO -
# backbone.layer3.2.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,665 - mmcv - INFO -
# backbone.layer3.2.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,665 - mmcv - INFO -
# backbone.layer3.2.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,666 - mmcv - INFO -
# backbone.layer3.2.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,667 - mmcv - INFO -
# backbone.layer3.3.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,667 - mmcv - INFO -
# backbone.layer3.3.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,668 - mmcv - INFO -
# backbone.layer3.3.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,668 - mmcv - INFO -
# backbone.layer3.3.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,669 - mmcv - INFO -
# backbone.layer3.3.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,670 - mmcv - INFO -
# backbone.layer3.3.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,670 - mmcv - INFO -
# backbone.layer3.3.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,671 - mmcv - INFO -
# backbone.layer3.3.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,672 - mmcv - INFO -
# backbone.layer3.3.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,673 - mmcv - INFO -
# backbone.layer3.3.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,673 - mmcv - INFO -
# backbone.layer3.3.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,674 - mmcv - INFO -
# backbone.layer3.4.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,674 - mmcv - INFO -
# backbone.layer3.4.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,675 - mmcv - INFO -
# backbone.layer3.4.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,675 - mmcv - INFO -
# backbone.layer3.4.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,676 - mmcv - INFO -
# backbone.layer3.4.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,677 - mmcv - INFO -
# backbone.layer3.4.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,678 - mmcv - INFO -
# backbone.layer3.4.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,678 - mmcv - INFO -
# backbone.layer3.4.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,679 - mmcv - INFO -
# backbone.layer3.4.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,679 - mmcv - INFO -
# backbone.layer3.4.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,680 - mmcv - INFO -
# backbone.layer3.4.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,680 - mmcv - INFO -
# backbone.layer3.5.conv1.weight - torch.Size([256, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,681 - mmcv - INFO -
# backbone.layer3.5.bn1.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,681 - mmcv - INFO -
# backbone.layer3.5.bn1.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,682 - mmcv - INFO -
# backbone.layer3.5.conv2.weight - torch.Size([256, 256, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,682 - mmcv - INFO -
# backbone.layer3.5.conv2.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,683 - mmcv - INFO -
# backbone.layer3.5.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,684 - mmcv - INFO -
# backbone.layer3.5.bn2.weight - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,684 - mmcv - INFO -
# backbone.layer3.5.bn2.bias - torch.Size([256]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,685 - mmcv - INFO -
# backbone.layer3.5.conv3.weight - torch.Size([1024, 256, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,685 - mmcv - INFO -
# backbone.layer3.5.bn3.weight - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,686 - mmcv - INFO -
# backbone.layer3.5.bn3.bias - torch.Size([1024]):
# PretrainedInit: load from torchvision://resnet50
# 2021-10-01 10:21:35,686 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,687 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,688 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,688 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,689 - mmcv - INFO -
# backbone.layer4.0.conv2.conv_offset.weight - torch.Size([27, 512, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,690 - mmcv - INFO -
# backbone.layer4.0.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,690 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,691 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,691 - mmcv - INFO -
# backbone.layer4.0.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,692 - mmcv - INFO -
# backbone.layer4.0.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,693 - mmcv - INFO -
# backbone.layer4.0.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,693 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([2048, 1024, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,694 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,695 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,695 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,696 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,697 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,697 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,698 - mmcv - INFO -
# backbone.layer4.1.conv2.conv_offset.weight - torch.Size([27, 512, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,699 - mmcv - INFO -
# backbone.layer4.1.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,699 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,700 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,700 - mmcv - INFO -
# backbone.layer4.1.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,701 - mmcv - INFO -
# backbone.layer4.1.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,702 - mmcv - INFO -
# backbone.layer4.1.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,702 - mmcv - INFO -
# backbone.layer4.2.conv1.weight - torch.Size([512, 2048, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,703 - mmcv - INFO -
# backbone.layer4.2.bn1.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,704 - mmcv - INFO -
# backbone.layer4.2.bn1.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,704 - mmcv - INFO -
# backbone.layer4.2.conv2.weight - torch.Size([512, 512, 3, 3]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,705 - mmcv - INFO -
# backbone.layer4.2.conv2.conv_offset.weight - torch.Size([27, 512, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,706 - mmcv - INFO -
# backbone.layer4.2.conv2.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,707 - mmcv - INFO -
# backbone.layer4.2.bn2.weight - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,707 - mmcv - INFO -
# backbone.layer4.2.bn2.bias - torch.Size([512]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,709 - mmcv - INFO -
# backbone.layer4.2.conv3.weight - torch.Size([2048, 512, 1, 1]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,709 - mmcv - INFO -
# backbone.layer4.2.bn3.weight - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,710 - mmcv - INFO -
# backbone.layer4.2.bn3.bias - torch.Size([2048]):
# PretrainedInit: load from torchvision://resnet50
#
# 2021-10-01 10:21:35,711 - mmcv - INFO -
# neck.lateral_convs.0.conv.weight - torch.Size([256, 512, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,711 - mmcv - INFO -
# neck.lateral_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,712 - mmcv - INFO -
# neck.lateral_convs.1.conv.weight - torch.Size([256, 1024, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,713 - mmcv - INFO -
# neck.lateral_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,713 - mmcv - INFO -
# neck.lateral_convs.2.conv.weight - torch.Size([256, 2048, 1, 1]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,714 - mmcv - INFO -
# neck.lateral_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,714 - mmcv - INFO -
# neck.fpn_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,715 - mmcv - INFO -
# neck.fpn_convs.0.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,716 - mmcv - INFO -
# neck.fpn_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,716 - mmcv - INFO -
# neck.fpn_convs.1.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,717 - mmcv - INFO -
# neck.fpn_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,717 - mmcv - INFO -
# neck.fpn_convs.2.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,718 - mmcv - INFO -
# neck.fpn_convs.3.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,718 - mmcv - INFO -
# neck.fpn_convs.3.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,719 - mmcv - INFO -
# neck.fpn_convs.4.conv.weight - torch.Size([256, 256, 3, 3]):
# XavierInit: gain=1, distribution=uniform, bias=0
#
# 2021-10-01 10:21:35,719 - mmcv - INFO -
# neck.fpn_convs.4.conv.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,720 - mmcv - INFO -
# bbox_head.cls_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
# 2021-10-01 10:21:35,721 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,721 - mmcv - INFO -
# bbox_head.cls_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,722 - mmcv - INFO -
# bbox_head.cls_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,722 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,723 - mmcv - INFO -
# bbox_head.cls_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,723 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,724 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,724 - mmcv - INFO -
# bbox_head.cls_convs.2.conv.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,725 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,726 - mmcv - INFO -
# bbox_head.cls_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,727 - mmcv - INFO -
# bbox_head.reg_convs.0.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,727 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,728 - mmcv - INFO -
# bbox_head.reg_convs.0.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,729 - mmcv - INFO -
# bbox_head.reg_convs.1.conv.weight - torch.Size([256, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,729 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,730 - mmcv - INFO -
# bbox_head.reg_convs.1.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,731 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,731 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.conv_offset.weight - torch.Size([27, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,732 - mmcv - INFO -
# bbox_head.reg_convs.2.conv.conv_offset.bias - torch.Size([27]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,732 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,733 - mmcv - INFO -
# bbox_head.reg_convs.2.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,734 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.conv.weight - torch.Size([256, 256, 3, 3]):
# Initialized by user-defined `init_weights` in ConvModule
#
# 2021-10-01 10:21:35,735 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,735 - mmcv - INFO -
# bbox_head.vfnet_reg_conv.gn.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,736 - mmcv - INFO -
# bbox_head.vfnet_reg.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,736 - mmcv - INFO -
# bbox_head.vfnet_reg.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,737 - mmcv - INFO -
# bbox_head.scales.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,738 - mmcv - INFO -
# bbox_head.scales.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,738 - mmcv - INFO -
# bbox_head.scales.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,739 - mmcv - INFO -
# bbox_head.scales.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,740 - mmcv - INFO -
# bbox_head.scales.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,741 - mmcv - INFO -
# bbox_head.vfnet_reg_refine_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,741 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.weight - torch.Size([4, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,742 - mmcv - INFO -
# bbox_head.vfnet_reg_refine.bias - torch.Size([4]):
# NormalInit: mean=0, std=0.01, bias=0
#
# 2021-10-01 10:21:35,743 - mmcv - INFO -
# bbox_head.scales_refine.0.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,745 - mmcv - INFO -
# bbox_head.scales_refine.1.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,745 - mmcv - INFO -
# bbox_head.scales_refine.2.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,746 - mmcv - INFO -
# bbox_head.scales_refine.3.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,747 - mmcv - INFO -
# bbox_head.scales_refine.4.scale - torch.Size([]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,747 - mmcv - INFO -
# bbox_head.vfnet_cls_dconv.weight - torch.Size([256, 256, 3, 3]):
# The value is the same before and after calling `init_weights` of VFNet
#
# 2021-10-01 10:21:35,748 - mmcv - INFO -
# bbox_head.vfnet_cls.weight - torch.Size([10, 256, 3, 3]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459
#
# 2021-10-01 10:21:35,749 - mmcv - INFO -
# bbox_head.vfnet_cls.bias - torch.Size([10]):
# NormalInit: mean=0, std=0.01, bias=-4.59511985013459

# %%
train_detector(model, datasets, cfg, distributed=False, validate=True)
# Out:
# 2021-10-01 10:21:36,960 - mmdet - INFO - Start running, host: root@2f4df6ced18c, work_dir: /opt/ml/detection/mmdetection/boostcamp/work_dirs/vfnet_resnest50_fpn_mdconv_c3-c5_mstrain_2x_coco
# 2021-10-01 10:21:36,962 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# 2021-10-01 10:21:36,964 - mmdet - INFO - workflow: [('train', 1)], max: 24 epochs
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/hooks/evaluation.py:192: UserWarning: runner.meta is None. Creating an empty one.
#   warnings.warn('runner.meta is None. Creating an empty one.')
# wandb: Currently logged in as: larcane (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.12.2<br/>
#                 Syncing run <strong style="color:#cdcd00">vfnet_resnest50_fpn_mdconv_c3-c5_mstrain_2x_coco</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/larcane/p-stage_object_detection" target="_blank">https://wandb.ai/larcane/p-stage_object_detection</a><br/>
#                 Run page: <a href="https://wandb.ai/larcane/p-stage_object_detection/runs/8vm1br2g" target="_blank">https://wandb.ai/larcane/p-stage_object_detection/runs/8vm1br2g</a><br/>
#                 Run data is saved locally in <code>/opt/ml/detection/mmdetection/boostcamp/notebook/wandb/run-20211001_102137-8vm1br2g</code><br/><br/>
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmdet/core/anchor/anchor_generator.py:361: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# 2021-10-01 10:21:56,747 - mmdet - INFO - Epoch [1][10/490]	lr: 3.287e-03, eta: 4:08:42, time: 1.270, data_time: 0.292, memory: 7035, loss_cls: 0.5648, loss_bbox: 0.9440, loss_bbox_rf: 1.3265, loss: 2.8353, grad_norm: 13.0649
# 2021-10-01 10:22:06,298 - mmdet - INFO - Epoch [1][20/490]	lr: 3.796e-03, eta: 3:37:41, time: 0.955, data_time: 0.019, memory: 7035, loss_cls: 0.7623, loss_bbox: 0.7937, loss_bbox_rf: 1.0809, loss: 2.6368, grad_norm: 6.4864
# 2021-10-01 10:22:15,862 - mmdet - INFO - Epoch [1][30/490]	lr: 4.305e-03, eta: 3:27:19, time: 0.956, data_time: 0.019, memory: 7035, loss_cls: 0.7403, loss_bbox: 0.7630, loss_bbox_rf: 1.0191, loss: 2.5224, grad_norm: 5.3885
# 2021-10-01 10:22:25,338 - mmdet - INFO - Epoch [1][40/490]	lr: 4.814e-03, eta: 3:21:38, time: 0.948, data_time: 0.016, memory: 7035, loss_cls: 0.7317, loss_bbox: 0.8021, loss_bbox_rf: 1.0672, loss: 2.6010, grad_norm: 4.9442
# 2021-10-01 10:22:34,946 - mmdet - INFO - Epoch [1][50/490]	lr: 5.323e-03, eta: 3:18:40, time: 0.961, data_time: 0.017, memory: 7035, loss_cls: 0.7882, loss_bbox: 0.7529, loss_bbox_rf: 1.0100, loss: 2.5510, grad_norm: 4.2685
# 2021-10-01 10:22:44,717 - mmdet - INFO - Epoch [1][60/490]	lr: 5.832e-03, eta: 3:17:10, time: 0.977, data_time: 0.019, memory: 7035, loss_cls: 0.7914, loss_bbox: 0.7461, loss_bbox_rf: 0.9934, loss: 2.5308, grad_norm: 4.4029
# 2021-10-01 10:22:54,313 - mmdet - INFO - Epoch [1][70/490]	lr: 6.341e-03, eta: 3:15:34, time: 0.960, data_time: 0.018, memory: 7035, loss_cls: 0.8163, loss_bbox: 0.7125, loss_bbox_rf: 0.9420, loss: 2.4707, grad_norm: 4.3305
# 2021-10-01 10:23:03,795 - mmdet - INFO - Epoch [1][80/490]	lr: 6.850e-03, eta: 3:14:03, time: 0.948, data_time: 0.017, memory: 7035, loss_cls: 0.8521, loss_bbox: 0.7129, loss_bbox_rf: 0.9405, loss: 2.5056, grad_norm: 5.3006
# 2021-10-01 10:23:13,493 - mmdet - INFO - Epoch [1][90/490]	lr: 7.360e-03, eta: 3:13:18, time: 0.970, data_time: 0.018, memory: 7035, loss_cls: 0.8418, loss_bbox: 0.7008, loss_bbox_rf: 0.9256, loss: 2.4682, grad_norm: 5.4377
# 2021-10-01 10:23:23,134 - mmdet - INFO - Epoch [1][100/490]	lr: 7.869e-03, eta: 3:12:33, time: 0.964, data_time: 0.016, memory: 7035, loss_cls: 0.7867, loss_bbox: 0.7281, loss_bbox_rf: 0.9544, loss: 2.4693, grad_norm: 4.8530
# 2021-10-01 10:23:32,478 - mmdet - INFO - Epoch [1][110/490]	lr: 8.378e-03, eta: 3:11:23, time: 0.934, data_time: 0.015, memory: 7035, loss_cls: 0.8100, loss_bbox: 0.6839, loss_bbox_rf: 0.9030, loss: 2.3968, grad_norm: 4.5564
# 2021-10-01 10:23:42,037 - mmdet - INFO - Epoch [1][120/490]	lr: 8.887e-03, eta: 3:10:44, time: 0.956, data_time: 0.018, memory: 7035, loss_cls: 0.7657, loss_bbox: 0.7065, loss_bbox_rf: 0.9415, loss: 2.4138, grad_norm: 4.2666
# 2021-10-01 10:23:51,888 - mmdet - INFO - Epoch [1][130/490]	lr: 9.396e-03, eta: 3:10:36, time: 0.985, data_time: 0.017, memory: 7035, loss_cls: 0.7573, loss_bbox: 0.7277, loss_bbox_rf: 0.9738, loss: 2.4588, grad_norm: 4.2764
# 2021-10-01 10:24:01,598 - mmdet - INFO - Epoch [1][140/490]	lr: 9.905e-03, eta: 3:10:16, time: 0.971, data_time: 0.018, memory: 7035, loss_cls: 0.7921, loss_bbox: 0.7082, loss_bbox_rf: 0.9490, loss: 2.4493, grad_norm: 3.7185
# 2021-10-01 10:24:11,357 - mmdet - INFO - Epoch [1][150/490]	lr: 1.041e-02, eta: 3:10:01, time: 0.976, data_time: 0.018, memory: 7035, loss_cls: 0.8105, loss_bbox: 0.6736, loss_bbox_rf: 0.8922, loss: 2.3763, grad_norm: 3.9020
# 2021-10-01 10:24:21,038 - mmdet - INFO - Epoch [1][160/490]	lr: 1.092e-02, eta: 3:09:41, time: 0.968, data_time: 0.019, memory: 7035, loss_cls: 1.0485, loss_bbox: 0.6633, loss_bbox_rf: 0.8715, loss: 2.5833, grad_norm: 4.1215
# 2021-10-01 10:24:30,740 - mmdet - INFO - Epoch [1][170/490]	lr: 1.143e-02, eta: 3:09:24, time: 0.970, data_time: 0.019, memory: 7035, loss_cls: 0.9165, loss_bbox: 0.6673, loss_bbox_rf: 0.8793, loss: 2.4630, grad_norm: 4.0680
# 2021-10-01 10:24:40,311 - mmdet - INFO - Epoch [1][180/490]	lr: 1.194e-02, eta: 3:08:59, time: 0.957, data_time: 0.017, memory: 7035, loss_cls: 0.9171, loss_bbox: 0.6575, loss_bbox_rf: 0.8795, loss: 2.4541, grad_norm: 4.1764
# 2021-10-01 10:24:49,733 - mmdet - INFO - Epoch [1][190/490]	lr: 1.245e-02, eta: 3:08:27, time: 0.942, data_time: 0.018, memory: 7035, loss_cls: 0.8598, loss_bbox: 0.6961, loss_bbox_rf: 0.9261, loss: 2.4819, grad_norm: 3.2590
# 2021-10-01 10:24:59,189 - mmdet - INFO - Epoch [1][200/490]	lr: 1.296e-02, eta: 3:07:59, time: 0.946, data_time: 0.017, memory: 7035, loss_cls: 0.9339, loss_bbox: 0.6714, loss_bbox_rf: 0.8859, loss: 2.4913, grad_norm: 3.6553
# 2021-10-01 10:25:09,093 - mmdet - INFO - Epoch [1][210/490]	lr: 1.347e-02, eta: 3:07:57, time: 0.990, data_time: 0.019, memory: 7035, loss_cls: 0.9229, loss_bbox: 0.7070, loss_bbox_rf: 0.9253, loss: 2.5552, grad_norm: 4.4493
# 2021-10-01 10:25:18,856 - mmdet - INFO - Epoch [1][220/490]	lr: 1.398e-02, eta: 3:07:47, time: 0.976, data_time: 0.019, memory: 7035, loss_cls: 0.8839, loss_bbox: 0.6523, loss_bbox_rf: 0.8810, loss: 2.4172, grad_norm: 3.4253
# 2021-10-01 10:25:28,435 - mmdet - INFO - Epoch [1][230/490]	lr: 1.449e-02, eta: 3:07:28, time: 0.958, data_time: 0.018, memory: 7035, loss_cls: 0.9311, loss_bbox: 0.6490, loss_bbox_rf: 0.8659, loss: 2.4460, grad_norm: 2.7492
# 2021-10-01 10:25:37,832 - mmdet - INFO - Epoch [1][240/490]	lr: 1.500e-02, eta: 3:07:01, time: 0.940, data_time: 0.016, memory: 7035, loss_cls: 0.8566, loss_bbox: 0.6358, loss_bbox_rf: 0.8333, loss: 2.3257, grad_norm: 3.0391
# 2021-10-01 10:25:47,193 - mmdet - INFO - Epoch [1][250/490]	lr: 1.551e-02, eta: 3:06:34, time: 0.936, data_time: 0.016, memory: 7035, loss_cls: 0.7734, loss_bbox: 0.6559, loss_bbox_rf: 0.8917, loss: 2.3210, grad_norm: 2.8901
# 2021-10-01 10:25:56,930 - mmdet - INFO - Epoch [1][260/490]	lr: 1.601e-02, eta: 3:06:25, time: 0.974, data_time: 0.018, memory: 7035, loss_cls: 0.8664, loss_bbox: 0.6273, loss_bbox_rf: 0.8295, loss: 2.3232, grad_norm: 3.1360
# 2021-10-01 10:26:06,486 - mmdet - INFO - Epoch [1][270/490]	lr: 1.652e-02, eta: 3:06:08, time: 0.956, data_time: 0.018, memory: 7035, loss_cls: 0.8382, loss_bbox: 0.6435, loss_bbox_rf: 0.8724, loss: 2.3541, grad_norm: 3.7538
# 2021-10-01 10:26:15,949 - mmdet - INFO - Epoch [1][280/490]	lr: 1.703e-02, eta: 3:05:47, time: 0.946, data_time: 0.016, memory: 7035, loss_cls: 0.8877, loss_bbox: 0.6097, loss_bbox_rf: 0.8106, loss: 2.3080, grad_norm: 3.5035
# 2021-10-01 10:26:25,648 - mmdet - INFO - Epoch [1][290/490]	lr: 1.754e-02, eta: 3:05:37, time: 0.970, data_time: 0.018, memory: 7035, loss_cls: 0.9094, loss_bbox: 0.6059, loss_bbox_rf: 0.8126, loss: 2.3279, grad_norm: 3.0695
# 2021-10-01 10:26:35,131 - mmdet - INFO - Epoch [1][300/490]	lr: 1.805e-02, eta: 3:05:19, time: 0.948, data_time: 0.018, memory: 7035, loss_cls: 0.8328, loss_bbox: 0.6146, loss_bbox_rf: 0.8156, loss: 2.2630, grad_norm: 2.2859
# 2021-10-01 10:26:44,555 - mmdet - INFO - Epoch [1][310/490]	lr: 1.856e-02, eta: 3:04:59, time: 0.942, data_time: 0.017, memory: 7035, loss_cls: 0.7933, loss_bbox: 0.6346, loss_bbox_rf: 0.8450, loss: 2.2728, grad_norm: 2.5780
# 2021-10-01 10:26:54,184 - mmdet - INFO - Epoch [1][320/490]	lr: 1.907e-02, eta: 3:04:47, time: 0.963, data_time: 0.017, memory: 7035, loss_cls: 0.8595, loss_bbox: 0.5998, loss_bbox_rf: 0.7961, loss: 2.2554, grad_norm: 2.8651
# 2021-10-01 10:27:03,682 - mmdet - INFO - Epoch [1][330/490]	lr: 1.958e-02, eta: 3:04:30, time: 0.950, data_time: 0.017, memory: 7035, loss_cls: 0.9376, loss_bbox: 0.5735, loss_bbox_rf: 0.7714, loss: 2.2825, grad_norm: 3.2907
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23494/259805608.py in <module>
# ----> 1 train_detector(model, datasets, cfg, distributed=False, validate=True)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmdet/apis/train.py in train_detector(model, dataset, cfg, distributed, validate, timestamp, meta)
#     172     elif cfg.load_from:
#     173         runner.load_checkpoint(cfg.load_from)
# --> 174     runner.run(data_loaders, cfg.workflow)
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in run(self, data_loaders, workflow, max_epochs, **kwargs)
#     125                     if mode == 'train' and self.epoch >= self._max_epochs:
#     126                         break
# --> 127                     epoch_runner(data_loaders[i], **kwargs)
#     128
#     129         time.sleep(1)  # wait for some hooks like loggers to finish
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/epoch_based_runner.py in train(self, data_loader, **kwargs)
#      49             self.call_hook('before_train_iter')
#      50             self.run_iter(data_batch, train_mode=True, **kwargs)
# ---> 51             self.call_hook('after_train_iter')
#      52             self._iter += 1
#      53
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/base_runner.py in call_hook(self, fn_name)
#     305         """
#     306         for hook in self._hooks:
# --> 307             getattr(hook, fn_name)(self)
#     308
#     309     def get_hook_info(self):
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/mmcv/runner/hooks/optimizer.py in after_train_iter(self, runner)
#      33     def after_train_iter(self, runner):
#      34         runner.optimizer.zero_grad()
# ---> 35         runner.outputs['loss'].backward()
#      36         if self.grad_clip is not None:
#      37             grad_norm = self.clip_grads(runner.model.parameters())
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /opt/conda/envs/detection/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:
