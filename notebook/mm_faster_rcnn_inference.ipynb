# %%
import mmcv
from mmcv import Config
from mmdet.datasets import (build_dataloader, build_dataset,
                            replace_ImageToTensor)
from mmdet.models import build_detector
from mmdet.apis import single_gpu_test
from mmcv.runner import load_checkpoint
import os
from mmcv.parallel import MMDataParallel
import pandas as pd
from pandas import DataFrame
from pycocotools.coco import COCO
import numpy as np

# %%
classes = ("General trash", "Paper", "Paper pack", "Metal", "Glass", 
           "Plastic", "Styrofoam", "Plastic bag", "Battery", "Clothing")

# config file 들고오기
cfg = Config.fromfile('./configs/cascade_rcnn/cascade_rcnn_x101_64x4d_fpn_1x_coco.py')

root='../dataset/'

epoch = 'latest'

# dataset config 수정
cfg.data.test.classes = classes
cfg.data.test.img_prefix = root
cfg.data.test.ann_file = root + 'test.json'
cfg.data.test.pipeline[1]['img_scale'] = (512,512) # Resize
cfg.data.test.test_mode = True

cfg.data.samples_per_gpu = 4

cfg.seed=2021
cfg.gpu_ids = [1]
cfg.work_dir = './work_dirs/cascade_rcnn_x101_64x4d_fpn_1x_coco_trash'

#cfg.model.roi_head.bbox_head.num_classes = 10

# for cascade r-cnn
for bbox_head in cfg.model.roi_head.bbox_head:
    bbox_head.num_classes = 10

cfg.optimizer_config.grad_clip = dict(max_norm=35, norm_type=2)
cfg.model.train_cfg = None

# %%
# build dataset & dataloader
dataset = build_dataset(cfg.data.test)
data_loader = build_dataloader(
        dataset,
        samples_per_gpu=1,
        workers_per_gpu=cfg.data.workers_per_gpu,
        dist=False,
        shuffle=False)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!

# %%
# checkpoint path
checkpoint_path = os.path.join(cfg.work_dir, f'{epoch}.pth')

model = build_detector(cfg.model, test_cfg=cfg.get('test_cfg')) # build detector
checkpoint = load_checkpoint(model, checkpoint_path, map_location='cpu') # ckpt load

model.CLASSES = dataset.CLASSES
model = MMDataParallel(model.cuda(), device_ids=[0])
# Out:
# /opt/ml/detection/mmdetection/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# Use load_from_local loader

# %%
output = single_gpu_test(model, data_loader, show_score_thr=0.05) # output 계산
# Out:
# [                                ] 2/4871, 1.8 task/s, elapsed: 1s, ETA:  2748s
# /opt/ml/detection/mmdetection/mmdet/core/anchor/anchor_generator.py:323: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /opt/ml/detection/mmdetection/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# [>>>>>>>>>>>>>>>>>>>>>>>>>>] 4871/4871, 12.3 task/s, elapsed: 396s, ETA:     0s

# %%
# submission 양식에 맞게 output 후처리
prediction_strings = []
file_names = []
coco = COCO(cfg.data.test.ann_file)
img_ids = coco.getImgIds()

class_num = 10
for i, out in enumerate(output):
    prediction_string = ''
    image_info = coco.loadImgs(coco.getImgIds(imgIds=i))[0]
    for j in range(class_num):
        for o in out[j]:
            prediction_string += str(j) + ' ' + str(o[4]) + ' ' + str(o[0]) + ' ' + str(o[1]) + ' ' + str(
                o[2]) + ' ' + str(o[3]) + ' '
        
    prediction_strings.append(prediction_string)
    file_names.append(image_info['file_name'])


submission = pd.DataFrame()
submission['image_id'] = file_names
submission['PredictionString'] = prediction_strings
submission.to_csv(os.path.join(cfg.work_dir, f'submission_{epoch}.csv'), index=None)
submission.head()
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
#         image_id                                   PredictionString
# 0  test/0000.jpg  0 0.21594998 341.73782 636.7697 396.9904 726.9...
# 1  test/0001.jpg  0 0.7141323 760.80005 664.88135 896.1344 995.5...
# 2  test/0002.jpg  0 0.6894192 292.68713 327.41306 1014.92175 378...
# 3  test/0003.jpg  0 0.22688335 79.09911 88.105804 206.20255 198....
# 4  test/0004.jpg  0 0.3006426 425.70517 259.6507 687.42444 567.2...

# %% [markdown]
# ## Visualization

# %%
# !apt install libcurl3 --yes
# !pip uninstall fiftyone-db-ubuntu1604 --yes
# !pip uninstall fiftyone --yes

# %%
import fiftyone as fo
from PIL import Image
from torchvision.transforms import functional as func

# %%
test_label = pd.read_csv(os.path.join(cfg.work_dir, f'submission_{epoch}.csv'),)

# %%
import json
annos_path = '../dataset/test.json'
with open(annos_path, 'rt', encoding='UTF-8') as annotations:
        coco = json.load(annotations)
        info = coco['info']
        licenses = coco['licenses']
        images = coco['images']
        annotations = coco['annotations']
        categories = coco['categories']

# %%
test_label = test_label[test_label['PredictionString'].isna()==False]

# %%
annotations
# Out:
# []

# %%
test_label
# Out:
#            image_id                                   PredictionString
# 0     test/0000.jpg  0 0.21594998 341.73782 636.7697 396.9904 726.9...
# 1     test/0001.jpg  0 0.7141323 760.80005 664.88135 896.1344 995.5...
# 2     test/0002.jpg  0 0.6894192 292.68713 327.41306 1014.92175 378...
# 3     test/0003.jpg  0 0.22688335 79.09911 88.105804 206.20255 198....
# 4     test/0004.jpg  0 0.3006426 425.70517 259.6507 687.42444 567.2...
# ...             ...                                                ...
# 4866  test/4866.jpg  0 0.5861999 295.73572 340.97736 667.60187 686....
# 4867  test/4867.jpg  0 0.40928185 631.9767 664.2442 774.4623 735.39...
# 4868  test/4868.jpg  0 0.7795237 549.6743 542.9815 678.0216 772.374...
# 4869  test/4869.jpg  0 0.49549615 472.7379 408.40784 658.49805 481....
# 4870  test/4870.jpg  0 0.3972848 241.60384 823.1376 292.51553 853.8...
#
# [4870 rows x 2 columns]

# %%
anno_id = 0
for idx,label in enumerate(test_label['PredictionString']):
    image_id = int(os.path.splitext(test_label['image_id'][idx].split('/'))[0])
    predict_list = label.split()
        
    for i in range(0,len(predict_list),6):
        anno={}
        
        anno['image_id'] = image_id
        anno['category_id'] = int(predict_list[i])
        x,y,width,height = float(predict_list[i+2]),float(predict_list[i+3]),float(predict_list[i+4]),float(predict_list[i+5])
        anno['bbox'] = [x,y,width,height]
        anno['segmentation'] = []
        anno['area'] = 0
        anno['iscrowd'] = 0
        anno['id'] = anno_id
        anno_id +=1
        
        annotations.append(anno)

# %%
coco['annotations']
# Out:
# [{'image_id': 0,
#   'category_id': 0,
#   'bbox': [341.73782, 636.7697, 396.9904, 726.9023],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id':

#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 77},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [868.5723, 239.5318, 915.5429, 323.19672],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 78},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [877.8997, 243.9729, 915.28937, 273.4273],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 79},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [88.038284, 280.533, 422.68512, 390.84598],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 80},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [422.5953, 264.3534, 639.6801, 327.23248],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 81},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [778.4704, 410.0786, 1024.0, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 82},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [0.0, 233.9448, 148.00317, 459.18576],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 83},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [276.04404, 295.74304, 295.73178, 387.08893],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 84},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [277.5378, 318.16183, 304.49582, 412.73587],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 85},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [311.76236, 327.1441, 1010.155, 433.68054],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 86},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [285.47745, 301.30258, 308.24734, 395.8795],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 87},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [874.1577, 465.25635, 1019.7584, 638.6305],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 88},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [654.4386, 266.41074, 755.9144, 324.05392],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 89},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [666.47266, 227.77176, 944.615, 325.6663],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 90},
#  {'image_id': 2,
#   'category_id': 0,
#   'bbox': [319.81104, 421.3686, 819.225, 735.35236],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 91},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [81.83205, 273.12296, 431.099, 605.88257],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 92},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [291.2048, 338.42258, 972.63086, 742.376],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 93},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [659.18823, 227.17851, 1017.9868, 328.08533],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 94},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [4.7600784, 239.19508, 144.46619, 375.3955],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 95},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [778.2136, 413.4447, 1024.0, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 96},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [422.71967, 264.3235, 639.8322, 327.1776],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 97},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [91.764984, 314.07745, 255.25204, 606.4929],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 98},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [993.7858, 304.3114, 1022.4831, 395.435],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 99},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [80.2809, 277.29605, 426.10394, 396.00497],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 100},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [160.36366, 301.30927, 327.63672, 592.5689],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 101},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [333.02197, 452.5373, 810.11597, 740.7652],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 102},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [868.0308, 239.38722, 916.1418, 322.66382],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 103},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [374.64456, 253.21489, 1019.57715, 379.17087],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 104},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [958.2377, 228.28847, 1023.6842, 396.03516],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 105},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [309.37488, 320.3724, 1011.57983, 379.37674],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 106},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [0.0, 278.35748, 153.70837, 464.50037],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 107},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [998.0891, 304.32562, 1024.0, 331.45288],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 108},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [962.73334, 228.67068, 1022.4903, 318.06882],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 109},
#  {'image_id': 2,
#   'category_id': 1,
#   'bbox': [959.2265, 298.44305, 1014.35455, 379.32483],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 110},
#  {'image_id': 2,
#   'category_id': 2,
#   'bbox': [4.039345, 236.57034, 146.95847, 376.4869],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 111},
#  {'image_id': 2,
#   'category_id': 3,
#   'bbox': [657.2517, 289.4109, 736.9783, 323.90332],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 112},
#  {'image_id': 2,
#   'category_id': 5,
#   'bbox': [868.70935, 240.05908, 914.0542, 323.31915],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 113},
#  {'image_id': 2,
#   'category_id': 5,
#   'bbox': [0.0, 322.99762, 108.52284, 460.44922],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 114},
#  {'image_id': 2,
#   'category_id': 5,
#   'bbox': [0.0, 234.02722, 144.77245, 459.58057],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 115},
#  {'image_id': 2,
#   'category_id': 5,
#   'bbox': [664.1757, 227.48938, 945.2912, 325.44818],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 116},
#  {'image_id': 2,
#   'category_id': 5,
#   'bbox': [68.4648, 225.94006, 166.43697, 258.01636],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 117},
#  {'image_id': 2,
#   'category_id': 6,
#   'bbox': [311.76236, 327.1441, 1010.155, 433.68054],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 118},
#  {'image_id': 2,
#   'category_id': 7,
#   'bbox': [0.0, 321.33295, 109.89201, 460.82684],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 119},
#  {'image_id': 2,
#   'category_id': 7,
#   'bbox': [422.0296, 264.6356, 640.0152, 327.6843],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 120},
#  {'image_id': 2,
#   'category_id': 7,
#   'bbox': [0.0, 233.116, 145.2561, 460.78195],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 121},
#  {'image_id': 3,
#   'category_id': 0,
#   'bbox': [79.09911, 88.105804, 206.20255, 198.69339],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 122},
#  {'image_id': 3,
#   'category_id': 0,
#   'bbox': [67.793945, 132.38083, 957.0437, 933.7135],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 123},
#  {'image_id': 3,
#   'category_id': 0,
#   'bbox': [0.0, 0.0, 1012.42456, 475.45758],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 124},
#  {'image_id': 3,
#   'category_id': 0,
#   'bbox': [1.0263367, 404.9078, 321.67865, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 125},
#  {'image_id': 3,
#   'category_id': 0,
#   'bbox': [182.83643, 476.88464, 1024.0, 1023.06885],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 126},
#  {'image_id': 3,
#   'category_id': 1,
#   'bbox': [14.907959, 87.30731, 998.9018, 949.2889],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 127},
#  {'image_id': 3,
#   'category_id': 5,
#   'bbox': [152.37888, 267.58344, 926.20056, 821.8757],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 128},
#  {'image_id': 3,
#   'category_id': 6,
#   'bbox': [158.45306, 265.99628, 922.94586, 816.2774],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id':

#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 155},
#  {'image_id': 5,
#   'category_id': 1,
#   'bbox': [356.5522, 224.54745, 776.3306, 716.92773],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 156},
#  {'image_id': 5,
#   'category_id': 2,
#   'bbox': [352.68585, 227.18268, 774.3188, 719.22076],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 157},
#  {'image_id': 5,
#   'category_id': 5,
#   'bbox': [427.76083, 673.59186, 466.76334, 707.3022],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 158},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [192.93137, 645.1219, 319.61172, 874.4605],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 159},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [199.13689, 544.7108, 282.6286, 712.9077],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 160},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [895.03796, 788.6172, 1023.124, 917.37463],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 161},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [600.4188, 0.0, 702.067, 84.394135],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 162},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [278.1822, 13.632675, 409.79407, 174.5046],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 163},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [7.755913, 256.88907, 214.02951, 501.4338],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 164},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [8.101326, 256.63055, 222.77216, 904.5192],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 165},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [300.3875, 631.3943, 378.3269, 748.1737],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 166},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [433.85516, 7.4181824, 677.69696, 277.66293],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 167},
#  {'image_id': 6,
#   'category_id': 0,
#   'bbox': [1.5808487, 809.10187, 83.80899, 940.4345],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 168},
#  {'image_id': 6,
#   'category_id': 1,
#   'bbox': [193.06262, 645.469, 321.79565, 874.3782],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 169},
#  {'image_id': 6,
#   'category_id': 1,
#   'bbox': [895.03796, 788.6172, 1023.124, 917.37463],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 170},
#  {'image_id': 6,
#   'category_id': 4,
#   'bbox': [0.0, 64.61798, 69.06525, 218.67606],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 171},
#  {'image_id': 6,
#   'category_id': 4,
#   'bbox': [338.98676, 455.6388, 835.5009, 723.2031],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 172},
#  {'image_id': 6,
#   'category_id': 4,
#   'bbox': [434.12482, 7.3483124, 676.8774, 277.74536],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 173},
#  {'image_id': 6,
#   'category_id': 5,
#   'bbox': [326.96448, 455.66324, 837.9801, 724.166],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 174},
#  {'image_id': 6,
#   'category_id': 5,
#   'bbox': [433.85516, 7.4181824, 677.69696, 277.66293],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 175},
#  {'image_id': 6,
#   'category_id': 5,
#   'bbox': [0.0, 64.979324, 69.0618, 218.65352],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 176},
#  {'image_id': 6,
#   'category_id': 5,
#   'bbox': [192.80309, 645.93555, 318.81085, 873.927],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 177},
#  {'image_id': 6,
#   'category_id': 6,
#   'bbox': [894.73785, 788.65137, 1022.7862, 917.5646],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 178},
#  {'image_id': 6,
#   'category_id': 6,
#   'bbox': [1.5808487, 809.10187, 83.80899, 940.4345],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 179},
#  {'image_id': 6,
#   'category_id': 6,
#   'bbox': [600.36816, 0.0, 701.96655, 84.4458],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 180},
#  {'image_id': 6,
#   'category_id': 6,
#   'bbox': [203.03983, 544.5202, 281.94907, 713.8687],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 181},
#  {'image_id': 6,
#   'category_id': 7,
#   'bbox': [280.46143, 10.862091, 408.99176, 175.03221],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 182},
#  {'image_id': 6,
#   'category_id': 7,
#   'bbox': [434.7418, 8.025696, 672.44275, 277.7443],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 183},
#  {'image_id': 6,
#   'category_id': 7,
#   'bbox': [192.93137, 645.1219, 319.61172, 874.4605],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 184},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [124.688354, 93.23703, 972.0143, 922.94165],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 185},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [335.47305, 0.0, 1019.80994, 214.44992],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 186},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [567.6407, 480.2448, 900.94476, 749.6773],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 187},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [883.6064, 895.8165, 1024.0, 1022.88477],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 188},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [361.68076, 51.063324, 999.09607, 655.69104],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 189},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [818.6465, 139.48148, 873.83984, 174.68921],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 190},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [1.7650805, 864.41296, 26.210598, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 191},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [124.05818, 165.00168, 503.44086, 707.44836],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 192},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [673.2959, 87.35827, 833.4392, 158.40268],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 193},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [257.70633, 573.95074, 362.12955, 741.6463],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 194},
#  {'image_id': 7,
#   'category_id': 0,
#   'bbox': [179.81793, 454.26968, 972.9556, 1012.65576],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 195},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [883.7468, 895.715, 1024.0, 1023.11115],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 196},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [203.42549, 886.1269, 612.66003, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 197},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [88.72888, 109.13275, 981.6836, 949.6954],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 198},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [96.311584, 467.0105, 923.92017, 913.64954],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 199},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [346.81226, 893.1458, 515.4601, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 200},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [122.73457, 152.94815, 581.39996, 813.6974],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 201},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [335.7976, 0.0, 1018.89197, 225.46951],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 202},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [440.30026, 909.1575, 605.027, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 203},
#  {'image_id': 7,
#   'category_id': 1,
#   'bbox': [183.4335, 173.18973, 452.9462, 724.62524],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 204},
#  {'image_id': 7,
#   'category_id': 5,
#   'bbox': [0.40537167, 864.3186, 23.386913, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 205},
#  {'image_id': 7,
#   'category_id': 5,
#   'bbox': [571.0421, 480.71088, 899.8561, 749.6297],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 206},
#  {'image_id': 7,
#   'category_id': 6,
#   'bbox': [568.649, 480.62073, 900.5661, 749.70776],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 207},
#  {'image_id': 7,
#   'category_id': 7,
#   'bbox': [50.358124, 65.02841, 989.1029, 986.8074],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 208},
#  {'image_id': 7,
#   'category_id': 7,
#   'bbox': [1.5077686, 864.4084, 23.871243, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 209},
#  {'image_id': 7,
#   'category_id': 7,
#   'bbox': [578.9811, 481.6996, 899.2245, 748.66296],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 210},
#  {'image_id': 7,
#   'category_id': 9,
#   'bbox': [313.06158, 104.181946, 967.5716, 753.73],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 211},
#  {'image_id': 7,
#   'category_id': 9,
#   'bbox': [567.6407, 480.2448, 900.94476, 749.6773],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 212},
#  {'image_id': 7,
#   'category_id': 9,
#   'bbox': [335.47305, 0.0, 1019.80994, 214.44992],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 213},
#  {'image_id': 7,
#   'category_id': 9,
#   'bbox': [173.06094, 417.1092, 984.90894, 1019.9107],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 214},
#  {'image_id': 8,
#   'category_id': 0,
#   'bbox': [104.00307, 907.07874, 169.32713, 971.4147],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 215},
#  {'image_id': 8,
#   'category_id': 0,
#   'bbox': [651.4965, 450.34164, 792.6595, 474.66843],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 216},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [642.989, 631.5932, 718.38477, 757.1379],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 217},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [599.78815, 348.48022, 738.491, 467.05615],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 218},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [104.0336, 907.0833, 169.28448, 971.4246],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 219},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [661.1473, 453.5584, 803.7537, 522.9823],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 220},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [362.35522, 500.99475, 455.77094, 599.85],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 221},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [773.25946, 274.15668, 977.1579, 612.4189],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 222},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [356.5799, 501.10602, 467.48773, 667.47687],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 223},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [678.702, 453.56183, 811.6846, 699.441],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 224},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [649.84155, 449.63306, 794.3788, 475.07104],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 225},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [708.79565, 513.6603, 810.2881, 616.0448],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 226},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [2.874771, 0.4423523, 311.93903, 261.29907],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 227},
#  {'image_id': 8,
#   'category_id': 1,
#   'bbox': [716.4159, 522.8942, 769.53296, 607.08026],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 228},
#  {'image_id': 8,
#   'category_id': 2,
#   'bbox': [599.0603, 348.6838, 738.501, 466.73666],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 229},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [695.9945, 477.0297, 813.40393, 627.56616],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 230},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [773.88043, 277.23242, 976.6275, 610.4892],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 231},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [541.8851, 433.89804, 733.3846, 661.46716],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 232},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [816.66925, 529.46857, 945.3747, 612.74274],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 233},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [846.5451, 545.1165, 901.94464, 602.05597],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 234},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [702.63837, 510.1431, 812.4821, 548.08417],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 235},
#  {'image_id': 8,
#   'category_id': 5,
#   'bbox': [2.2137604, 363.39337, 278.67694, 635.1313],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 236},
#  {'image_id': 8,
#   'category_id': 6,
#   'bbox': [773.60754, 276.32166, 976.52686, 611.2255],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 237},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [161.52017, 500.09875, 468.91562, 968.02954],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 238},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [1.4809113, 615.5832, 185.33902, 878.47687],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 239},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [398.52063, 473.21198, 688.391, 879.9627],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 240},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [2.018631, 364.2063, 279.1939, 635.1577],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 241},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [530.239, 440.11026, 800.54175, 700.1188],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 242},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [698.4252, 507.23468, 816.79846, 618.9255],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 243},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [361.70874, 501.40662, 460.26233, 603.8688],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 244},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [359.21176, 500.62515, 470.64883, 686.30316],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 245},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [683.0903, 470.6289, 810.53937, 698.0471],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 246},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [148.19362, 508.9588, 335.79126, 672.5733],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 247},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [549.6032, 430.72626, 723.3813, 633.8599],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 248},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [0.0, 591.0526, 44.052166, 674.1415],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 249},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [716.4159, 522.8942, 769.53296, 607.08026],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 250},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [705.8832, 515.0014, 806.99976, 576.81085],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 251},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [0.0, 510.9303, 44.810913, 682.72974],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 252},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [0.0, 556.9478, 38.382385, 616.815],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 253},
#  {'image_id': 8,
#   'category_id': 7,
#   'bbox': [143.81589, 466.33362, 725.5912, 948.6494],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 254},
#  {'image_id': 9,
#   'category_id': 0,
#   'bbox': [275.90845, 111.13071, 663.94556, 966.803],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 255},
#  {'image_id': 9,
#   'category_id': 0,
#   'bbox': [282.66168, 499.64404, 650.5227, 928.28503],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 256},
#  {'image_id': 9,
#   'category_id': 0,
#   'bbox': [294.7812, 727.54425, 624.52716, 974.3001],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 257},
#  {'image_id': 9,
#   'category_id': 0,
#   'bbox': [282.3459, 748.90924, 311.5276, 871.1346],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 258},
#  {'image_id': 9,
#   'category_id': 1,
#   'bbox': [277.65045, 132.32486, 664.4572, 981.1439],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 259},
#  {'image_id': 9,
#   'category_id': 9,
#   'bbox': [206.11365, 126.2785, 366.51538, 748.9834],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 260},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [661.07324, 19.152924, 1021.9375, 556.77527],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 261},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [45.178673, 665.1842, 211.1347, 769.68567],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 262},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [53.296143, 684.2277, 193.24928, 717.51447],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 263},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [0.0, 835.8438, 265.69128, 1023.1412],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 264},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [890.40393, 609.4093, 948.6549, 671.646],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 265},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [54.187088, 706.98517, 341.93347, 820.7636],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 266},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [73.08446, 690.03845, 193.21852, 743.08704],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 267},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [62.27327, 709.40424, 216.88414, 739.9915],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 268},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [184.72762, 877.25885, 565.88855, 1018.81976],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 269},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [50.295227, 654.6134, 190.84698, 720.8943],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 270},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [109.80033, 673.07434, 187.37091, 715.56274],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 271},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [59.484047, 698.85144, 199.3811, 727.3091],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 272},
#  {'image_id': 10,
#   'category_id': 0,
#   'bbox': [289.6359, 822.0662, 344.40524, 853.4489],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 273},
#  {'image_id': 10,
#   'category_id': 3,
#   'bbox': [163.11069, 543.5352, 258.3362, 576.4914],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 274},
#  {'image_id': 10,
#   'category_id': 3,
#   'bbox': [214.24892, 321.61395, 652.29987, 481.9167],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 275},
#  {'image_id': 10,
#   'category_id': 4,
#   'bbox': [212.02277, 320.88702, 654.43286, 482.96448],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 276},
#  {'image_id': 10,
#   'category_id': 4,
#   'bbox': [58.507965, 590.01373, 437.41147, 725.5861],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 277},
#  {'image_id': 10,
#   'category_id': 5,
#   'bbox': [214.24892, 321.61395, 652.29987, 481.9167],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 278},
#  {'image_id': 10,
#   'category_id': 5,
#   'bbox': [54.50479, 591.7824, 440.7633, 724.89594],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 279},
#  {'image_id': 10,
#   'category_id': 6,
#   'bbox': [890.3392, 609.5398, 948.6136, 671.57275],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 280},
#  {'image_id': 10,
#   'category_id': 7,
#   'bbox': [1.1656342, 838.2213, 259.2699, 1022.079],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 281},
#  {'image_id': 10,
#   'category_id': 7,
#   'bbox': [188.38626, 876.3413, 554.5648, 1018.9618],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 282},
#  {'image_id': 10,
#   'category_id': 7,
#   'bbox': [52.018875, 590.1908, 446.90784, 732.10767],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 283},
#  {'image_id': 11,
#   'category_id': 0,
#   'bbox': [0.0, 117.15564, 951.573, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 284},
#  {'image_id': 11,
#   'category_id': 0,
#   'bbox': [459.84012, 122.384224, 776.77356, 367.32974],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 285},
#  {'image_id': 11,
#   'category_id': 0,
#   'bbox': [698.02295, 254.70659, 751.3241, 285.2902],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 286},
#  {'image_id': 11,
#   'category_id': 0,
#   'bbox': [620.6641, 247.03444, 772.3267, 360.05823],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 287},
#  {'image_id': 11,
#   'category_id': 1,
#   'bbox': [101.811005, 128.57315, 1024.0, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 288},
#  {'image_id': 11,
#   'category_id': 1,
#   'bbox': [698.02295, 254.70659, 751.3241, 285.2902],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 289},
#  {'image_id': 11,
#   'category_id': 1,
#   'bbox': [605.73, 247.16455, 779.70264, 340.75134],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 290},
#  {'image_id': 11,
#   'category_id': 2,
#   'bbox': [714.4157, 327.24634, 914.3038, 472.09894],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 291},
#  {'image_id': 11,
#   'category_id': 3,
#   'bbox': [715.48706, 325.736, 916.2999, 471.40738],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 292},
#  {'image_id': 11,
#   'category_id': 3,
#   'bbox': [626.51166, 245.49706, 777.6192, 363.17975],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 293},
#  {'image_id': 11,
#   'category_id': 3,
#   'bbox': [460.34378, 122.000565, 774.85986, 377.7827],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 294},
#  {'image_id': 11,
#   'category_id': 3,
#   'bbox': [619.07935, 240.76321, 775.6488, 471.78488],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 295},
#  {'image_id': 11,
#   'category_id': 3,
#   'bbox': [657.92566, 319.35733, 915.4956, 552.9486],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 296},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [615.13983, 308.20636, 767.65485, 482.92963],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 297},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [103.70364, 640.7129, 648.5044, 837.19495],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 298},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [454.94464, 121.90127, 777.77496, 369.7037],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 299},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [539.48065, 860.60004, 651.97406, 1019.6507],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 300},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [727.1538, 718.3382, 863.6582, 880.67084],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 301},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [486.3356, 268.8405, 1010.4696, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 302},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [672.6636, 414.99405, 882.74805, 567.46704],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 303},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [621.3832, 200.97136, 777.49316, 443.1142],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 304},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [3.9172363, 612.79694, 1012.20404, 1009.6308],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 305},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [626.51166, 245.49706, 777.6192, 363.17975],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 306},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [573.83545, 636.87836, 877.7001, 913.1092],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 307},
#  {'image_id': 11,
#   'category_id': 4,
#   'bbox': [634.4614, 319.19803, 922.94116, 464.35245],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
# ...
#  {'image_id': 46,
#   'category_id': 5,
#   'bbox': [4.4161377, 3.4059753, 386.60837, 229.21942],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 898},
#  {'image_id': 46,
#   'category_id': 5,
#   'bbox': [730.18567, 461.7056, 1024.0, 1019.5923],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 899},
#  {'image_id': 46,
#   'category_id': 5,
#   'bbox': [796.28076, 8.846741, 1022.5443, 945.1586],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 900},
#  {'image_id': 46,
#   'category_id': 5,
#   'bbox': [820.7408, 108.26909, 1022.30414, 615.8846],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 901},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [501.28186, 530.62854, 727.5906, 807.4866],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 902},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [184.19778, 455.1623, 565.8329, 776.5949],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 903},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [572.11237, 416.21274, 756.133, 581.6226],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 904},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [651.522, 484.42615, 821.4873, 693.6256],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 905},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [164.0177, 428.7011, 451.71912, 644.74615],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 906},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [418.6772, 426.87714, 603.33923, 541.07056],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 907},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [421.62103, 427.8616, 532.5688, 508.53128],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 908},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [509.83142, 431.06516, 574.2826, 489.6826],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 909},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [4.4161377, 3.4059753, 386.60837, 229.21942],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 910},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [507.08868, 429.4141, 606.7861, 516.57886],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 911},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [532.254, 492.79825, 586.219, 535.93005],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 912},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [483.59167, 430.74304, 809.08923, 815.78394],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 913},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [452.21246, 478.98465, 572.60004, 538.33356],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 914},
#  {'image_id': 46,
#   'category_id': 7,
#   'bbox': [426.7386, 421.41757, 604.821, 659.3587],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 915},
#  {'image_id': 47,
#   'category_id': 0,
#   'bbox': [156.47629, 220.52429, 826.1094, 823.65247],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 916},
#  {'image_id': 47,
#   'category_id': 0,
#   'bbox': [541.9753, 236.73398, 818.753, 800.5216],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 917},
#  {'image_id': 47,
#   'category_id': 1,
#   'bbox': [155.56564, 222.07632, 828.48096, 823.37256],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 918},
#  {'image_id': 47,
#   'category_id': 7,
#   'bbox': [150.85062, 226.9165, 706.1963, 818.7329],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 919},
#  {'image_id': 48,
#   'category_id': 0,
#   'bbox': [0.55099297, 758.4314, 36.039658, 892.5217],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 920},
#  {'image_id': 48,
#   'category_id': 0,
#   'bbox': [167.60564, 40.31935, 487.2199, 417.5379],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 921},
#  {'image_id': 48,
#   'category_id': 0,
#   'bbox': [78.866196, 410.2007, 536.9525, 585.8342],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 922},
#  {'image_id': 48,
#   'category_id': 1,
#   'bbox': [36.634064, 22.532349, 567.0443, 854.4851],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 923},
#  {'image_id': 48,
#   'category_id': 1,
#   'bbox': [60.873505, 386.66345, 537.81006, 847.05615],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 924},
#  {'image_id': 48,
#   'category_id': 1,
#   'bbox': [168.0859, 37.62587, 483.21768, 422.66748],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 925},
#  {'image_id': 48,
#   'category_id': 1,
#   'bbox': [76.9402, 410.05072, 537.86847, 591.19556],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 926},
#  {'image_id': 48,
#   'category_id': 1,
#   'bbox': [55.779083, 36.969604, 184.91747, 565.53906],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 927},
#  {'image_id': 48,
#   'category_id': 6,
#   'bbox': [78.866196, 410.2007, 536.9525, 585.8342],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 928},
#  {'image_id': 48,
#   'category_id': 7,
#   'bbox': [0.8795948, 757.7774, 33.910774, 892.6552],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 929},
#  {'image_id': 49,
#   'category_id': 0,
#   'bbox': [207.55936, 185.84534, 663.60693, 935.92773],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 930},
#  {'image_id': 49,
#   'category_id': 1,
#   'bbox': [207.65775, 186.22461, 663.8646, 935.5055],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 931},
#  {'image_id': 49,
#   'category_id': 7,
#   'bbox': [208.44296, 185.44626, 663.4136, 935.4623],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 932},
#  {'image_id': 50,
#   'category_id': 0,
#   'bbox': [304.22818, 0.0, 394.3007, 145.14174],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 933},
#  {'image_id': 50,
#   'category_id': 0,
#   'bbox': [658.93445, 302.4219, 813.9043, 375.23477],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 934},
#  {'image_id': 50,
#   'category_id': 0,
#   'bbox': [400.07855, 144.0951, 665.0594, 743.3696],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 935},
#  {'image_id': 50,
#   'category_id': 0,
#   'bbox': [660.3911, 324.52133, 702.2594, 374.86594],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 936},
#  {'image_id': 50,
#   'category_id': 1,
#   'bbox': [400.29782, 146.82831, 663.98315, 741.884],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 937},
#  {'image_id': 50,
#   'category_id': 1,
#   'bbox': [660.70593, 302.93628, 812.79944, 375.0124],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 938},
#  {'image_id': 50,
#   'category_id': 2,
#   'bbox': [400.37866, 146.51697, 664.2267, 741.27594],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 939},
#  {'image_id': 50,
#   'category_id': 3,
#   'bbox': [658.44525, 302.7644, 813.92865, 375.26898],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 940},
#  {'image_id': 50,
#   'category_id': 5,
#   'bbox': [658.2693, 302.4577, 814.0791, 375.28302],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 941},
#  {'image_id': 50,
#   'category_id': 7,
#   'bbox': [398.7378, 146.54578, 665.92444, 743.2773],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 942},
#  {'image_id': 50,
#   'category_id': 7,
#   'bbox': [660.0934, 302.8143, 812.834, 375.0873],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 943},
#  {'image_id': 50,
#   'category_id': 7,
#   'bbox': [304.02325, 0.0, 394.20654, 145.3927],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 944},
#  {'image_id': 51,
#   'category_id': 0,
#   'bbox': [494.34253, 620.1413, 569.2942, 670.6728],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 945},
#  {'image_id': 51,
#   'category_id': 0,
#   'bbox': [141.47586, 817.7415, 345.67014, 939.80316],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 946},
#  {'image_id': 51,
#   'category_id': 1,
#   'bbox': [141.30057, 818.81866, 346.3154, 939.5251],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 947},
#  {'image_id': 51,
#   'category_id': 1,
#   'bbox': [0.0, 377.91534, 42.060387, 544.65314],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 948},
#  {'image_id': 51,
#   'category_id': 1,
#   'bbox': [418.51984, 607.04803, 640.9051, 779.7376],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 949},
#  {'image_id': 51,
#   'category_id': 5,
#   'bbox': [0.0, 377.7591, 40.256683, 545.46344],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 950},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [437.3421, 397.22202, 767.1276, 602.0186],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 951},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [418.0926, 605.5759, 640.392, 787.8634],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 952},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [82.984, 476.07285, 291.58142, 643.9686],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 953},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [486.15912, 532.05414, 784.1485, 674.4687],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 954},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [347.78412, 453.64517, 494.1018, 614.2528],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 955},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [515.12933, 536.42566, 777.10345, 615.4713],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 956},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [506.67218, 399.78085, 770.71674, 518.6147],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 957},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [422.97296, 402.96692, 784.6381, 776.7344],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 958},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [431.29108, 430.51825, 510.97455, 615.67267],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 959},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [116.912384, 464.16342, 426.82425, 659.31055],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 960},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [194.03944, 464.24182, 510.68866, 605.10535],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 961},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [489.52026, 607.0857, 763.71765, 673.099],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 962},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [280.27713, 562.40515, 381.69205, 681.3766],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 963},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [141.07611, 818.79614, 347.49112, 939.81775],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 964},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [548.74115, 540.9435, 730.9245, 596.40857],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 965},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [209.46881, 471.12054, 386.21417, 562.36346],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 966},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [442.59344, 412.78046, 557.9082, 642.81805],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 967},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [581.6571, 398.8181, 764.4525, 477.67688],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 968},
#  {'image_id': 51,
#   'category_id': 6,
#   'bbox': [228.8483, 468.16772, 394.2253, 682.85547],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 969},
#  {'image_id': 52,
#   'category_id': 0,
#   'bbox': [202.71518, 21.186829, 945.28174, 992.62445],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 970},
#  {'image_id': 52,
#   'category_id': 1,
#   'bbox': [231.62903, 17.373016, 919.2362, 1001.75024],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 971},
#  {'image_id': 52,
#   'category_id': 1,
#   'bbox': [2.8266296, 32.142303, 356.56445, 1017.2097],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 972},
#  {'image_id': 52,
#   'category_id': 1,
#   'bbox': [301.18256, 462.36273, 890.4516, 999.8715],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 973},
#  {'image_id': 52,
#   'category_id': 7,
#   'bbox': [232.63904, 21.723145, 915.5748, 991.2265],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 974},
#  {'image_id': 52,
#   'category_id': 9,
#   'bbox': [224.97324, 19.49936, 924.7003, 1001.81274],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 975},
#  {'image_id': 53,
#   'category_id': 0,
#   'bbox': [322.60135, 153.70227, 771.04785, 834.8521],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 976},
#  {'image_id': 53,
#   'category_id': 0,
#   'bbox': [97.3454, 0.0, 572.86365, 442.73315],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 977},
#  {'image_id': 53,
#   'category_id': 0,
#   'bbox': [87.44153, 0.0, 695.66284, 832.9147],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 978},
#  {'image_id': 53,
#   'category_id': 9,
#   'bbox': [327.44565, 152.58875, 764.42957, 832.59235],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 979},
#  {'image_id': 54,
#   'category_id': 0,
#   'bbox': [360.80817, 269.39252, 699.6884, 629.9532],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 980},
#  {'image_id': 55,
#   'category_id': 2,
#   'bbox': [405.83505, 441.49652, 713.9496, 687.5063],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 981},
#  {'image_id': 55,
#   'category_id': 3,
#   'bbox': [667.68024, 568.11035, 785.5662, 670.2971],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 982},
#  {'image_id': 55,
#   'category_id': 4,
#   'bbox': [566.0389, 786.05695, 609.82916, 866.21063],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 983},
#  {'image_id': 56,
#   'category_id': 0,
#   'bbox': [423.497, 369.60785, 730.1236, 601.8183],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 984},
#  {'image_id': 56,
#   'category_id': 1,
#   'bbox': [422.92316, 369.17975, 730.2054, 603.3147],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 985},
#  {'image_id': 56,
#   'category_id': 2,
#   'bbox': [424.2614, 371.33652, 732.18756, 601.0991],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 986},
#  {'image_id': 56,
#   'category_id': 6,
#   'bbox': [422.92316, 369.17975, 730.2054, 603.3147],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 987},
#  {'image_id': 57,
#   'category_id': 0,
#   'bbox': [879.57294, 183.19226, 1023.74664, 725.07666],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 988},
#  {'image_id': 57,
#   'category_id': 0,
#   'bbox': [440.2392, 910.2194, 565.7856, 1023.3847],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 989},
#  {'image_id': 57,
#   'category_id': 0,
#   'bbox': [434.3666, 887.63324, 649.29065, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 990},
#  {'image_id': 57,
#   'category_id': 0,
#   'bbox': [564.63806, 646.0172, 636.23865, 677.8153],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 991},
#  {'image_id': 57,
#   'category_id': 0,
#   'bbox': [16.404663, 755.11304, 538.119, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 992},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [150.88696, 375.8569, 686.43396, 928.82324],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 993},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [880.9552, 219.59079, 1023.12415, 725.0951],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 994},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [442.61874, 894.5622, 646.4019, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 995},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [6.8272705, 761.68475, 619.85443, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 996},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [458.54095, 910.2299, 561.4572, 1021.7863],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 997},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [4.2435303, 326.86298, 241.91937, 1023.8946],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 998},
#  {'image_id': 57,
#   'category_id': 1,
#   'bbox': [438.0862, 762.738, 642.5209, 1024.0],
#   'segmentation': [],
#   'area': 0,
#   'iscrowd': 0,
#   'id': 999},
#  ...]

# %%
coco['annotations'] = annotations
with open(os.path.join(cfg.work_dir, f'test_{epoch}.json'), 'wt', encoding='UTF-8') as f:
        json.dump(coco,f)

# %%
dataset = fo.Dataset.from_dir(dataset_type=fo.types.COCODetectionDataset,
                              data_path='../dataset',
                              labels_path=os.path.join(cfg.work_dir, f'test_{epoch}.json'))
# Out:
#  100% |███████████████| 4871/4871 [1.2m elapsed, 0s remaining, 71.4 samples/s]

# %%
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=true&handleId=2d9426f3-e8ff-4f92-abed-afeb62ee0c6e"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
